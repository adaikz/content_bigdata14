# %% [markdown]
# # Закон Ципфа
#
# Экспериментальная проверим закон Ципфа на материале романа «Преступление и наказание»

# %%
! wget --no-verbose -nc https://www.dropbox.com/s/59libg6rvt31ff3/dostoevsky.txt

# %%
with open('dostoevsky.txt', encoding='cp1251') as f:
    book = f.readlines()

# %%
book
# Out:
# ['    Федор Михайлович Достоевский\n',
#  '\n',
#  '    Преступление и наказание\n',
#  '\n',
#  '    Роман в шести частях с эпилогом\n',
#  '      \n',
#  '\n',
#  '    Часть первая\n',
#  '\n',
#  '    I\n',
#  '       В начале июля, в чрезвычайно жаркое время, под вечер, один молодой человек вышел из своей каморки, которую нанимал от жильцов в С -- м переулке, на улицу и медленно, как бы в нерешимости, отправился к К -- ну мосту. \n',
# ...

# %%
len(book)
# Out:
# 4364

# %%
# !pip install nltk

# %%
import nltk

# %%
# nltk.download("punkt")
# nltk.download("wordnet")

# %% [markdown]
# Токенизируем текст

# %%
tokens = nltk.word_tokenize(' '.join(book))
tokens
# Out:
# ['Федор',
#  'Михайлович',
#  'Достоевский',
#  'Преступление',
#  'и',
#  'наказание',
#  'Роман',
#  'в',
#  'шести',
#  'частях',
#  'с',
#  'эпилогом',
#  'Часть',
#  'первая',
#  'I',
#  'В',
#  'начале',
#  'июля',
#  ',',
#  'в',
#  'чрезвычайно',
#  'жаркое',
#  'время',
#  ',',
#  'под',
#  'вечер',
#  ',',
#  'один',
#  'молодой',
#  'человек',
#  'вышел',
#  'из',
#  'своей',
#  'каморки',
#  ',',
#  'которую',
#  'нанимал',
#  'от',
#  'жильцов',
#  'в',
#  'С',
#  '--',
#  'м',
#  'переулке',
#  ',',
#  'на',
#  'улицу',
#  'и',
#  'медленно',
#  ',',
#  'как',
#  'бы',
#  'в',
#  'нерешимости',
#  ',',
#  'отправился',
#  'к',
#  'К',
#  '--',
#  'ну',
#  'мосту',
#  '.',
#  'Он',
#  'благополучно',
#  'избегнул',
#  'встречи',
#  'с',
#  'своею',
#  'хозяйкой',
#  'на',
#  'лестнице',
#  '.',
#  'Каморка',
#  'его',
#  'приходилась',
#  'под',
#  'самою',
#  'кровлей',
#  'высокого',
#  'пятиэтажного',
#  'дома',
#  'и',
#  'походила',
#  'более',
#  'на',
#  'шкаф',
# ...

# %% [markdown]
# Будьте внимательны - токенизатор не приводит слова к нижнему регистру, надо это сделать самостоятельно

# %%
tokens = [x.lower() for x in tokens]
tokens[:25]
# Out:
# ['федор',
#  'михайлович',
#  'достоевский',
#  'преступление',
#  'и',
#  'наказание',
#  'роман',
#  'в',
#  'шести',
#  'частях',
#  'с',
#  'эпилогом',
#  'часть',
#  'первая',
#  'i',
#  'в',
#  'начале',
#  'июля',
#  ',',
#  'в',
#  'чрезвычайно',
#  'жаркое',
#  'время',
#  ',',
#  'под']

# %%
from collections import Counter

# %%
f = Counter(tokens)
f
# Out:
# Counter({'федор': 2,
#          'михайлович': 1,
#          'достоевский': 79,
#          'преступление': 63,
#          'и': 9175,
#          'наказание': 24,
#          'роман': 24,
#          'в': 4313,
#          'шести': 8,
#          'частях': 3,
#          'с': 2233,
#          'эпилогом': 1,
#          'часть': 33,
#          'первая': 8,
#          'i': 10,
#          'начале': 18,
#          'июля': 1,
#          ',': 26977,
#          'чрезвычайно': 44,
#          'жаркое': 1,
#          'время': 243,
#          'под': 168,
#          'вечер': 25,
#          'один': 200,
#          'молодой': 50,
#          'человек': 261,
#          'вышел': 76,
#          'из': 548,
#          'своей': 100,
#          'каморки': 4,
#          'которую': 66,
#          'нанимал': 2,
#          'от': 565,
#          'жильцов': 13,
#          '--': 6365,
#          'м': 2,
#          'переулке': 4,
#          'на': 2549,
#          'улицу': 46,
#          'медленно': 29,
# ...

# %%
f = sorted(list(f.items()), key=lambda x: x[1], reverse=True)
f
# Out:
# [(',', 26977),
#  ('и', 9175),
#  ('.', 9057),
#  ('--', 6365),
#  ('в', 4313),
#  ('не', 3933),
#  ('что', 3355),
#  ('!', 3277),
#  ('он', 2932),
#  ('на', 2549),
#  ('я', 2449),
#  ('?', 2264),
#  ('с', 2233),
#  ('...', 2143),
#  ('а', 1836),
#  ('как', 1726),
#  ('это', 1446),
#  ('его', 1322),
#  (';', 1298),
#  ('но', 1213),
#  ('так', 1203),
#  ('``', 1190),
#  ("''", 1184),
#  ('же', 1178),
#  ('да', 1061),
#  ('к', 1025),
#  (':', 1011),
#  ('вы', 976),
#  ('всё', 973),
#  ('она', 917),
#  ('бы', 889),
#  ('было', 823),
#  ('у', 729),
#  ('по', 719),
#  ('то', 712),
#  ('еще', 712),
#  ('даже', 709),
#  ('за', 688),
#  ('ее', 661),
#  ('только', 655),
#  ('ты', 601),
#  ('раскольников', 591),
#  ('теперь', 583),
#  ('вот', 581),
#  ('вдруг', 573),
#  ('от', 565),
#  ('о', 550),
#  ('уже', 549),
#  ('из', 548),
#  ('ему', 547),
#  ('меня', 537),
#  ('ну', 525),
#  ('ведь', 510),
#  ('мне', 495),
#  ('уж', 484),
#  ('быть', 476),
#  ('был', 465),
#  ('до', 460),
# ...

# %%
# import re
# print(re.match('[А-Яа-я]+', 'достоевский'))

# %% [markdown]
# Заменим в отсортированном списке каждое слово на его ранг и построим график

# %%
fn = [(x[1], i+1) for i, x in enumerate(f)]
fn
# Out:
# [(26977, 1),
#  (9175, 2),
#  (9057, 3),
#  (6365, 4),
#  (4313, 5),
#  (3933, 6),
#  (3355, 7),
#  (3277, 8),
#  (2932, 9),
#  (2549, 10),
#  (2449, 11),
#  (2264, 12),
#  (2233, 13),
#  (2143, 14),
#  (1836, 15),
#  (1726, 16),
#  (1446, 17),
#  (1322, 18),
#  (1298, 19),
#  (1213, 20),
#  (1203, 21),
#  (1190, 22),
#  (1184, 23),
#  (1178, 24),
#  (1061, 25),
#  (1025, 26),
#  (1011, 27),
#  (976, 28),
#  (973, 29),
#  (917, 30),
#  (889, 31),
#  (823, 32),
#  (729, 33),
#  (719, 34),
#  (712, 35),
#  (712, 36),
#  (709, 37),
#  (688, 38),
#  (661, 39),
#  (655, 40),
#  (601, 41),
#  (591, 42),
#  (583, 43),
#  (581, 44),
#  (573, 45),
#  (565, 46),
#  (550, 47),
#  (549, 48),
#  (548, 49),
#  (547, 50),
#  (537, 51),
#  (525, 52),
#  (510, 53),
#  (495, 54),
#  (484, 55),
#  (476, 56),
#  (465, 57),
#  (460, 58),
#  (425, 59),
#  (424, 60),
#  (413, 61),
#  (403, 62),
#  (388, 63),
#  (385, 64),
#  (379, 65),
#  (378, 66),
#  (376, 67),
#  (375, 68),
#  (371, 69),
#  (364, 70),
# ...

# %%
[x[0]*x[1] for x in fn[:10]]
# Out:
# [26977, 18350, 27171, 25460, 21565, 23598, 23485, 26216, 26388, 25490]

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([x[1] for x in fn[1000:]], [x[0] for x in fn[1000:]]);

# %% [markdown]
# # Стеммер и лемматизатор для английского языка

# %%
from nltk.stem import PorterStemmer

# %%
porter_stemmer = PorterStemmer()
porter_stemmer.stem('am')
# Out:
# 'am'

# %%
txt = 'John has three dogs and he went for a walk with them'

# %%
tokens_txt = nltk.word_tokenize(txt)
tokens_txt
# Out:
# ['John',
#  'has',
#  'three',
#  'dogs',
#  'and',
#  'he',
#  'went',
#  'for',
#  'a',
#  'walk',
#  'with',
#  'them']

# %%
tokens_stem = [porter_stemmer.stem(x) for x in tokens_txt]
tokens_stem
# Out:
# ['john',
#  'ha',
#  'three',
#  'dog',
#  'and',
#  'he',
#  'went',
#  'for',
#  'a',
#  'walk',
#  'with',
#  'them']

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
wordnet_lemmatizer.lemmatize('is', pos=wordnet.VERB)
# Out:
# 'is'

# %%
wordnet_lemmatizer.lemmatize('went', pos=wordnet.VERB)
# Out:
# 'went'

# %%
tokens_stem = [wordnet_lemmatizer.lemmatize(x, pos=wordnet.VERB) for x in tokens_txt]
tokens_stem
# Out:
# ['John',
#  'have',
#  'three',
#  'dog',
#  'and',
#  'he',
#  'go',
#  'for',
#  'a',
#  'walk',
#  'with',
#  'them']

# %%
# nltk.download('averaged_perceptron_tagger')

# %%
tag = nltk.pos_tag(['went', 'is'])

from nltk.corpus import wordnet

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else: return wordnet.NOUN
    
get_wordnet_pos(tag[0][1])
# Out:
# 'v'

# %%
tag
# Out:
# [('went', 'VBD'), ('is', 'VBZ')]

# %%
wrd = 'walked'
wordnet_lemmatizer.lemmatize(wrd, pos=get_wordnet_pos(nltk.pos_tag([wrd])[0][1]))
# Out:
# 'walk'

# %% [markdown]
# # Стеммер для русского языка

# %%
from snowballstemmer import RussianStemmer
stemmer = RussianStemmer()

# %%
txt = 'Бигдатые пацаны'
stemmer.stemWords(txt.lower().split())
# Out:
# ['бигдат', 'паца']

# %%
stem_txt = stemmer.stemWords(nltk.word_tokenize(txt))
stem_txt
# Out:
# ['Бигдат', 'паца']

# %%
nltk.word_tokenize('1 два 3')

# %%
tokens

# %% [markdown]
# Измерим время работы на тексте романа

# %%
' '.join(tokens[:50])
# Out:
# 'федор михайлович достоевский преступление и наказание роман в шести частях с эпилогом часть первая i в начале июля , в чрезвычайно жаркое время , под вечер , один молодой человек вышел из своей каморки , которую нанимал от жильцов в с -- м переулке , на улицу и медленно ,'

# %%
# %%time
stem_txt = stemmer.stemWords(tokens[:2000])
print(stem_txt[:50])
# Out:
# ['федор', 'михайлович', 'достоевск', 'преступлен', 'и', 'наказан', 'рома', 'в', 'шест', 'част', 'с', 'эпилог', 'част', 'перв', 'i', 'в', 'начал', 'июл', ',', 'в', 'чрезвычайн', 'жарк', 'врем', ',', 'под', 'вечер', ',', 'один', 'молод', 'человек', 'вышел', 'из', 'сво', 'каморк', ',', 'котор', 'нанима', 'от', 'жильц', 'в', 'с', '--', 'м', 'переулк', ',', 'на', 'улиц', 'и', 'медлен', ',']
# CPU times: user 56.1 ms, sys: 3.34 ms, total: 59.5 ms
# Wall time: 58.3 ms

# %% [markdown]
# # Морфоанализаторы для русского языка

# %%
# !pip install pymorphy2
# !pip install pymystem3

# %%
import pymystem3

# %%
mystem = pymystem3.Mystem()

# %% [markdown]
# Обратим внимание - mystem сам токенизирует текст внутри себя. Если наше текст уже токенизирован, то нужно передавать токены по одному

# %%
# %%time
lemm_mystem = [mystem.lemmatize(x) for x in tokens[:2000]]
print(lemm_mystem[:50])
# Out:
# [['федор', '\n'], ['михайлович', '\n'], ['достоевский', '\n'], ['преступление', '\n'], ['и', '\n'], ['наказание', '\n'], ['роман', '\n'], ['в', '\n'], ['шесть', '\n'], ['часть', '\n'], ['с', '\n'], ['эпилог', '\n'], ['часть', '\n'], ['первый', '\n'], ['i', '\n'], ['в', '\n'], ['начало', '\n'], ['июль', '\n'], [',\n'], ['в', '\n'], ['чрезвычайно', '\n'], ['жаркий', '\n'], ['время', '\n'], [',\n'], ['под', '\n'], ['вечер', '\n'], [',\n'], ['один', '\n'], ['молодой', '\n'], ['человек', '\n'], ['выходить', '\n'], ['из', '\n'], ['свой', '\n'], ['каморка', '\n'], [',\n'], ['который', '\n'], ['нанимать', '\n'], ['от', '\n'], ['жилец', '\n'], ['в', '\n'], ['с', '\n'], ['--\n'], ['м', '\n'], ['переулок', '\n'], [',\n'], ['на', '\n'], ['улица', '\n'], ['и', '\n'], ['медленно', '\n'], [',\n']]
# CPU times: user 66.9 ms, sys: 95.8 ms, total: 163 ms
# Wall time: 1.43 s

# %%
[mystem.lemmatize(x) for x in txt.lower().split()]
# Out:
# [['бигдатый', '\n'], ['пацан', '\n']]

# %%
' '.join(tokens[:2000])
# Out:
# "федор михайлович достоевский преступление и наказание роман в шести частях с эпилогом часть первая i в начале июля , в чрезвычайно жаркое время , под вечер , один молодой человек вышел из своей каморки , которую нанимал от жильцов в с -- м переулке , на улицу и медленно , как бы в нерешимости , отправился к к -- ну мосту . он благополучно избегнул встречи с своею хозяйкой на лестнице . каморка его приходилась под самою кровлей высокого пятиэтажного дома и походила более на шкаф , чем на квартиру . квартирная же хозяйка его , у которой он нанимал эту каморку с обедом и прислугой , помещалась одною лестницей ниже , в отдельной квартире , и каждый раз , при выходе на улицу , ему непременно надо было проходить мимо хозяйкиной кухни , почти всегда настежь отворенной на лестницу . и каждый раз молодой человек , проходя мимо , чувствовал какое-то болезненное и трусливое ощущение , которого стыдился и от которого морщился . он был должен кругом хозяйке и боялся с нею встретиться . не то что
# ...

# %%
# %%time
lemm_mystem = mystem.lemmatize(' '.join(tokens[:2000]))
print(''.join(lemm_mystem))
# Out:
# федор михайлович достоевский преступление и наказание роман в шесть часть с эпилог часть первый i в начало июль , в чрезвычайно жаркий время , под вечер , один молодой человек выходить из свой каморка , который нанимать от жилец в с -- м переулок , на улица и медленно , как бы в нерешимость , отправляться к к -- ну мост . он благополучно избегать встреча с свой хозяйка на лестница . каморка его приходиться под сам кровля высокий пятиэтажный дом и походить более на шкаф , чем на квартира . квартирный же хозяйка он , у который он нанимать этот каморка с обед и прислуга , помещаться один лестница ниже , в отдельный квартира , и каждый раз , при выход на улица , он непременно надо быть проходить мимо хозяйкин кухня , почти всегда настежь отворять на лестница . и каждый раз молодой человек , проходить мимо , чувствовать какой-то болезненный и трусливый ощущение , который стыдиться и от который морщиться . он быть должный кругом хозяйка и бояться с она встречаться . не то чтоб он быть так 
# ...

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
morph.parse('Эрдоган')
# Out:
# [Parse(word='эрдоган', tag=OpencorporaTag('PRTS,perf,past,pssv masc,sing'), normal_form='эрдогать', score=0.7727272727272728, methods_stack=((<FakeDictionary>, 'эрдоган', 614, 71), (<KnownSuffixAnalyzer>, 'оган'))),
#  Parse(word='эрдоган', tag=OpencorporaTag('NOUN,anim,masc,Name sing,nomn'), normal_form='эрдоган', score=0.13636363636363638, methods_stack=((<FakeDictionary>, 'эрдоган', 26, 0), (<KnownSuffixAnalyzer>, 'оган'))),
#  Parse(word='эрдоган', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='эрдоганый', score=0.04545454545454546, methods_stack=((<FakeDictionary>, 'эрдоган', 238, 54), (<KnownSuffixAnalyzer>, 'оган'))),
#  Parse(word='эрдоган', tag=OpencorporaTag('ADJS masc,sing'), normal_form='эрдоганый', score=0.04545454545454546, methods_stack=((<FakeDictionary>, 'эрдоган', 188, 27), (<KnownSuffixAnalyzer>, 'оган')))]

# %%
morph.parse('Эрдоган')[0].normal_form
# Out:
# 'эрдогать'

# %%
# %%time
lemm_pymorph = [morph.parse(x)[0].normal_form for x in tokens[:2000]]
print(lemm_pymorph[:50])
# Out:
# ['фёдор', 'михайло', 'достоевский', 'преступление', 'и', 'наказание', 'роман', 'в', 'шесть', 'часть', 'с', 'эпилог', 'часть', 'один', 'i', 'в', 'начало', 'июль', ',', 'в', 'чрезвычайно', 'жаркое', 'время', ',', 'под', 'вечер', ',', 'один', 'молодая', 'человек', 'выйти', 'из', 'свой', 'каморка', ',', 'который', 'нанимать', 'от', 'жильцов', 'в', 'с', '--', 'метр', 'переулок', ',', 'на', 'улица', 'и', 'медленно', ',']
# CPU times: user 514 ms, sys: 0 ns, total: 514 ms
# Wall time: 531 ms
